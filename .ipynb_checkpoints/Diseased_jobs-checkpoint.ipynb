# %%
import pandas as pd
import numpy as np
import psycopg2
from sqlalchemy import create_engine

# %%
#Bringing the employment csv data into a dataframe
emp_data = "employment_data_by_state.csv"
emp_data = pd.read_csv(emp_data)

emp_data.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#      TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1,943,760      0.4  1000.000  1.00  ...    16.22   25.63   38.28  18,030
# 1     73,860      1.1    38.001  0.72  ...    46.01   63.87   90.06  48,650
# 2      1,390      5.6     0.716  0.53  ...    91.31       #       #  79,530
# 3     28,600      1.8    14.712  0.93  ...    48.55   70.79       #  50,180
# 4        970      6.4     0.498  1.43  ...        *       *       *  16,310
#
#    A_PCT25 A_MEDIAN  A_PCT75  A_PCT90 ANNUAL HOURLY
# 0   22,400   33,740   53,310   79,630    NaN    NaN
# 1   68,030   95,710  132,860  187,330    NaN    NaN
# 2  125,570  189,920        #        #    NaN    NaN
# 3   68,990  100,980  147,250        #    NaN    NaN
# 4   17,390   19,210   32,290   63,390   True    NaN
#
# [5 rows x 25 columns]

# %%
#Getting the data types for the columns in emp_data to see if any need to be converted
emp_data.dtypes
# Out:
# AREA          int64
# ST           object
# STATE        object
# OCC_CODE     object
# OCC_TITLE    object
# OCC_GROUP    object
# TOT_EMP      object
# EMP_PRSE     object
# JOBS_1000    object
# LOC_Q        object
# H_MEAN       object
# A_MEAN       object
# MEAN_PRSE    object
# H_PCT10      object
# H_PCT25      object
# H_MEDIAN     object
# H_PCT75      object
# H_PCT90      object
# A_PCT10      object
# A_PCT25      object
# A_MEDIAN     object
# A_PCT75      object
# A_PCT90      object
# ANNUAL       object
# HOURLY       object
# dtype: object

# %%
#Removing rows that do not have employment data
emp_data = emp_data[emp_data.TOT_EMP != '**']

# %%
#Removing commas and converting the column to float from object for future calculations
emp_data["TOT_EMP"] = emp_data["TOT_EMP"].str.replace(",","").astype(float)

#Showing the cleaned dataframe
emp_data
# Out:
#        AREA  ST           STATE OCC_CODE  \
# 0         1  AL         Alabama  00-0000
# 1         1  AL         Alabama  11-0000
# 2         1  AL         Alabama  11-1011
# 3         1  AL         Alabama  11-1021
# 4         1  AL         Alabama  11-1031
# 5         1  AL         Alabama  11-2011
# 6         1  AL         Alabama  11-2021
# 7         1  AL         Alabama  11-2022
# 8         1  AL         Alabama  11-2031
# 9         1  AL         Alabama  11-3011
# 10        1  AL         Alabama  11-3021
# 11        1  AL         Alabama  11-3031
# 12        1  AL         Alabama  11-3051
# 13        1  AL         Alabama  11-3061
# 14        1  AL         Alabama  11-3071
# 15        1  AL         Alabama  11-3111
# 16        1  AL         Alabama  11-3121
# 17        1  AL         Alabama  11-3131
# 18        1  AL         Alabama  11-9021
# 19        1  AL         Alabama  11-9031
# 20        1  AL         Alabama  11-9032
# 21        1  AL         Alabama  11-9033
# 22        1  AL         Alabama  11-9039
# 23        1  AL         Alabama  11-9041
# 24        1  AL         Alabama  11-9051
# 25        1  AL         Alabama  11-9061
# 26        1  AL         Alabama  11-9081
# 27        1  AL         Alabama  11-9111
# 28        1  AL         Alabama  11-9121
# 29        1  AL         Alabama  11-9131
# 36862                                         Carpenters  detailed      360.0
# 36863               Cement Masons and Concrete Finishers  detailed       40.0
# 36864                              Construction Laborers  detailed      380.0
# 36865  Operating Engineers and Other Construction Equ...  detailed      120.0
# 36866                                       Electricians  detailed      170.0
# 36867             Painters, Construction and Maintenance  detailed       60.0
# 36868            Plumbers, Pipefitters, and Steamfitters  detailed       60.0
# 36871  Installation, Maintenance, and Repair Occupations     major     1350.0
# 36872  First-Line Supervisors of Mechanics, Installer...  detailed      150.0
# 36873  Telecommunications Equipment Installers and Re...  detailed       40.0
# 36874       Automotive Service Technicians and Mechanics  detailed      160.0
# 36875  Bus and Truck Mechanics and Diesel Engine Spec...  detailed       40.0
# 36876  Heating, Air Conditioning, and Refrigeration M...  detailed       80.0
# 36878            Maintenance and Repair Workers, General  detailed      620.0
# 36879                             Production Occupations     major      730.0
# 36880  First-Line Supervisors of Production and Opera...  detailed      130.0
# 36881                          Butchers and Meat Cutters  detailed       70.0
# 36882           Welders, Cutters, Solderers, and Brazers  detailed       40.0
# 36883                   Laundry and Dry-Cleaning Workers  detailed      110.0
# 36884     Transportation and Material Moving Occupations     major     2170.0
# 36885  First-Line Supervisors of Transportation and M...  detailed       70.0
# 36886              Bus Drivers, School or Special Client  detailed       70.0
# 36887                               Driver/Sales Workers  detailed       60.0
# 36888            Heavy and Tractor-Trailer Truck Drivers  detailed      310.0
# 36889           Light Truck or Delivery Services Drivers  detailed      130.0
# 36890                        Taxi Drivers and Chauffeurs  detailed       60.0
# 36891       Captains, Mates, and Pilots of Water Vessels  detailed      160.0
# 36892       Automotive and Watercraft Service Attendants  detailed       70.0
# 36894             Industrial Truck and Tractor Operators  detailed       60.0
# 36896                        Packers and Packagers, Hand  detailed      100.0
#
#       EMP_PRSE JOBS_1000  LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0          0.4  1000.000   1.00  ...    16.22   25.63   38.28  18,030
# 1          1.1    38.001   0.72  ...    46.01   63.87   90.06  48,650
# 2          5.6     0.716   0.53  ...    91.31       #       #  79,530
# 3          1.8    14.712   0.93  ...    48.55   70.79       #  50,180
# 4          6.4     0.498   1.43  ...        *       *       *  16,310
# 5         20.7     0.028   0.16  ...    54.62   72.16   80.33  45,390
# 6          6.3     0.394   0.24  ...    52.36   74.05   94.61  54,750
# 7          4.8     1.230   0.47  ...    49.95   68.18   93.07  56,880
# 8         10.2     0.263   0.53  ...    38.19   50.20   72.42  45,230
# 9          7.1     0.384   0.20  ...    43.04   55.71   68.30  48,060
# 10         4.0     1.646   0.61  ...    57.27   73.19   88.29  77,970
# 11         2.5     2.526   0.60  ...    55.28   73.90   99.80  66,830
# 12         4.0     1.817   1.45  ...    46.52   59.23   76.03  60,030
# 13         2.8     0.437   0.91  ...    51.81   61.10   72.57  63,750
# 14         8.9     0.529   0.61  ...    39.58   54.35   67.63  38,850
# 15         8.6     0.032   0.30  ...    48.46   61.26   91.22  49,250
# 16         3.4     0.658   0.66  ...    46.06   59.39   76.99  59,890
_MEDIAN  A_PCT75  A_PCT90 ANNUAL HOURLY
# 0       22,400   33,740   53,310   79,630    NaN    NaN
# 1       68,030   95,710  132,860  187,330    NaN    NaN
# 2      125,570  189,920        #        #    NaN    NaN
# 3       68,990  100,980  147,250        #    NaN    NaN
# 4       17,390   19,210   32,290   63,390   True    NaN
# 5       61,320  113,610  150,100  167,090    NaN    NaN
# 6       74,590  108,920  154,020  196,780    NaN    NaN
# 7       72,030  103,890  141,820  193,580    NaN    NaN
# 8       58,670   79,440  104,410  150,640    NaN    NaN
# 9       68,700   89,520  115,880  142,050    NaN    NaN
# 10      94,750  119,120  152,230  183,650    NaN    NaN
# 11      86,290  114,980  153,710  207,580    NaN    NaN
# 12      76,330   96,770  123,200  158,150    NaN    NaN
# 13      81,850  107,760  127,080  150,950    NaN    NaN
# 14      60,180   82,330  113,060  140,680    NaN    NaN
# 15      79,720  100,790  127,420  189,740    NaN    NaN
# 16      76,100   95,810  123,530  160,150    NaN    NaN
# 17      86,110  105,180  129,780  163,770    NaN    NaN
# 18      68,280   86,350  110,180  146,960    NaN    NaN
# 19      27,750   35,060   46,640   64,110    NaN    NaN
# 20      70,020   80,960   95,430  105,740   True    NaN
# 21      69,200   93,250  130,120  195,830    NaN    NaN
# 22      78,250   98,110  115,110  130,590    NaN    NaN
# 23     112,680  133,910  160,700  190,830    NaN    NaN
# 24      42,280   52,350   70,850   94,560    NaN    NaN
# 25      49,940   68,910   89,910  137,070    NaN    NaN
# 26      37,440   52,020   61,410   73,880    NaN    NaN
# 27      70,500   90,500  119,740  157,040    NaN    NaN
# 28      87,910  104,690  124,890  165,740    NaN    NaN
# 29      70,080   77,070   84,810   92,340    NaN    NaN
# ...        ...      ...      ...      ...    ...    ...
# 36862   38,110   51,210   59,360   64,050    NaN    NaN
# 36863   35,060   38,610   45,360   50,330    NaN    NaN
# 36864   28,460   32,980   40,560   50,110    NaN    NaN
# 36865   33,880   39,810   47,660   52,480    NaN    NaN
# 36866   40,750   50,580   67,870   91,310    NaN    NaN
# 36867   32,070   37,000   43,880   49,430    NaN    NaN
# 36868   41,130   47,200   58,060   69,840    NaN    NaN
# 36871   27,480   34,580   46,820   61,180    NaN    NaN
# 36872   43,730   49,760   63,010   78,110    NaN    NaN
# 36873   41,310   56,070   72,940   83,230    NaN    NaN
# 36874   27,190   32,320   39,590   51,180    NaN    NaN
# 36875   28,210   34,240   46,850   54,500    NaN    NaN
# 36876   29,110   36,760   49,070   84,540    NaN    NaN
# 36878   24,840   29,650   36,920   46,500    NaN    NaN
# 36879   25,450   38,900   56,280   68,000    NaN    NaN
# 36880   43,210   58,580   81,880  107,870    NaN    NaN
# 36881   25,160   31,610   40,380   48,830    NaN    NaN
# 36882   40,380   53,290   59,050   61,870    NaN    NaN
# 36883   20,250   21,920   24,520   28,120    NaN    NaN
# 36884   22,820   28,690   37,630   48,540    NaN    NaN
# 36885   34,620   40,880   53,570   85,130    NaN    NaN
# 36886   22,840   26,620   30,640   35,030    NaN    NaN
# 36887   21,350   23,970   29,930   36,700    NaN    NaN
# 36888   27,550   35,580   41,540   49,780    NaN    NaN
# 36889   21,720   24,530   32,480   38,350    NaN    NaN
# 36890   22,760   25,600   30,100   44,120    NaN    NaN
# 36891   28,420   41,120   49,880   75,190    NaN    NaN
# 36892   20,670   23,430   27,330   30,560    NaN    NaN
# 36894   22,550   24,870   35,980   41,290    NaN    NaN
# 36896   20,260   20,450   21,070   24,270    NaN    NaN
#
# [35335 rows x 25 columns]

# %%
#Dropping unnecessary columns 
emp_data.drop(emp_data.iloc[:, 7:69], inplace=True, axis=1)

emp_data.head(5)
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#      TOT_EMP
# 0  1943760.0
# 1    73860.0
# 2     1390.0
# 3    28600.0
# 4      970.0

# %%
emp_data = emp_data.rename(columns={"AREA": "area", "ST":"st", "STATE": "state", "OCC_CODE":"occ_code", "OCC_TITLE": "occ_title", "OCC_GROUP":"occ_group", "TOT_EMP":"tot_emp"})

# %%
#Filtering on major occupation group
major_cat = emp_data[(emp_data.occ_group == 'major')]

#Filtering the detail occupation group
detail_cat = emp_data[(emp_data.occ_group == 'detailed')]

# #Dropping unnecessary columns 
# major_cat.drop(major_cat.iloc[:, 7:69], inplace=True, axis=1) 
# detail_cat.drop(detail_cat.iloc[:, 7:69], inplace=True, axis=1)

major_cat.head(2)
# Out:
#     area  st    state occ_code                                      occ_title  \
# 1      1  AL  Alabama  11-0000                         Management Occupations
# 34     1  AL  Alabama  13-0000  Business and Financial Operations Occupations
#
#    occ_group  tot_emp
# 1      major  73860.0
# 34     major  74370.0

# %%
detail_cat.head(2)
# Out:
#    area  st    state occ_code                        occ_title occ_group  \
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
#
#    tot_emp
# 2   1390.0
# 3  28600.0

# %%
#sorting by total employment descending so the highest number for every group will be first
major_cat = major_cat.sort_values(['st', 'tot_emp'], ascending=False) 

major_cat.head(5)
# Out:
#        area  st    state occ_code  \
# 35664    56  WY  Wyoming  43-0000
# 35715    56  WY  Wyoming  47-0000
# 35601    56  WY  Wyoming  35-0000
# 35646    56  WY  Wyoming  41-0000
# 35841    56  WY  Wyoming  53-0000
#
#                                               occ_title occ_group  tot_emp
# 35664     Office and Administrative Support Occupations     major  34250.0
# 35715           Construction and Extraction Occupations     major  26820.0
# 35601  Food Preparation and Serving Related Occupations     major  25310.0
# 35646                     Sales and Related Occupations     major  23920.0
# 35841    Transportation and Material Moving Occupations     major  22070.0

# %%
#sorting by total employment descending so the highest number for every group will be first
detail_cat = detail_cat.sort_values(['st', 'tot_emp'], ascending=False) 

detail_cat.head(5)
# Out:
#        area  st    state occ_code  \
# 35653    56  WY  Wyoming  41-2031
# 35707    56  WY  Wyoming  43-9061
# 35649    56  WY  Wyoming  41-2011
# 35848    56  WY  Wyoming  53-3032
# 35610    56  WY  Wyoming  35-3021
#
#                                                occ_title occ_group  tot_emp
# 35653                                Retail Salespersons  detailed   8200.0
# 35707                             Office Clerks, General  detailed   7460.0
# 35649                                           Cashiers  detailed   6760.0
# 35848            Heavy and Tractor-Trailer Truck Drivers  detailed   6340.0
# 35610  Combined Food Preparation and Serving Workers,...  detailed   5460.0

# %%
#dropping ALL duplicate values and keeping the first value since it's the highest (HA! no loops)
major_cat.drop_duplicates(subset ='st', 
                     keep='first', inplace = True) 

major_cat.head(5)
# Out:
#        area  st          state occ_code  \
# 35664    56  WY        Wyoming  43-0000
# 34321    54  WV  West Virginia  43-0000
# 35034    55  WI      Wisconsin  43-0000
# 33613    53  WA     Washington  43-0000
# 32182    50  VT        Vermont  43-0000
#
#                                            occ_title occ_group   tot_emp
# 35664  Office and Administrative Support Occupations     major   34250.0
# 34321  Office and Administrative Support Occupations     major  104270.0
# 35034  Office and Administrative Support Occupations     major  409200.0
# 33613  Office and Administrative Support Occupations     major  442170.0
# 32182  Office and Administrative Support Occupations     major   40650.0

# %%
#dropping ALL duplicate values and keeping the first value since it's the highest (HA! no loops)
detail_cat.drop_duplicates(subset ='st', 
                     keep='first', inplace = True)

detail_cat.head(5)
# Out:
#        area  st          state occ_code            occ_title occ_group  \
# 35653    56  WY        Wyoming  41-2031  Retail Salespersons  detailed
# 34308    54  WV  West Virginia  41-2031  Retail Salespersons  detailed
# 35019    55  WI      Wisconsin  41-2031  Retail Salespersons  detailed
# 33598    53  WA     Washington  41-2031  Retail Salespersons  detailed
# 32166    50  VT        Vermont  41-2011             Cashiers  detailed
#
#         tot_emp
# 35653    8200.0
# 34308   23100.0
# 35019   81160.0
# 33598  103220.0
# 32166    9340.0

# %%
#Bringing the covid-19 csv data into a dataframe 
covid_data = "Covid19_03-05-2020.csv"
covid_data = pd.read_csv(covid_data)
covid_data.head(1)
# Out:
#   Province/State  Country/Region          Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  2020-03-05T14:53:03      67466    2902
#
#    Recovered  Latitude  Longitude
# 0      40592   30.9756   112.2707

# %%
#Splitting the 'Province/State' column to get the US cities and states in separate columns
covid_data[['City', 'US_state']] = covid_data['Province/State'].str.split(',\s+', expand=True)

#Dropping the 'Province/State' column
covid_data = covid_data.drop('Province/State', axis=1)

covid_data.head(5)
# Out:
#    Country/Region          Last Update  Confirmed  Deaths  Recovered  \
# 0  Mainland China  2020-03-05T14:53:03      67466    2902      40592
# 1     South Korea  2020-03-05T09:03:09       6088      35         41
# 2           Italy  2020-03-05T17:43:03       3858     148        414
# 3            Iran  2020-03-05T13:43:04       3513     107        739
# 4  Mainland China  2020-03-05T09:23:03       1351       7       1181
#
#    Latitude  Longitude       City US_state
# 0   30.9756   112.2707      Hubei     None
# 1   36.0000   128.0000        NaN      NaN
# 2   43.0000    12.0000        NaN      NaN
# 3   32.0000    53.0000        NaN      NaN
# 4   23.3417   113.4244  Guangdong     None

# %%
#Reanming the Country/Region column to get rid of the "/" and replace it with an underscore "_" to manipulate the data
covid_data = covid_data.rename(columns={"Country/Region": "country_region",
                                        "Last Update":"last_update",
                                        "Confirmed": "confirmed",
                                        "Deaths":"deaths",
                                       "Recovered":"recovered",
                                       "Latitude":"latitude",
                                       "Longitude":"longitude",
                                       "City":"city",
                                       "US_state":"us_state"})

# %%
#Filtering on US data
US_covid = covid_data[(covid_data.country_region == 'US')]

US_covid.head(5)
# Out:
#    country_region          last_update  confirmed  deaths  recovered  \
# 46             US  2020-03-05T22:03:17         51      10          1
# 50             US  2020-03-02T19:53:03         45       0          0
# 61             US  2020-03-05T22:53:03         20       0          1
# 63             US  2020-03-05T20:23:07         18       1          0
# 64             US  2020-03-05T21:33:03         18       0          0
#
#     latitude  longitude                                         city us_state
# 46   47.5480  -121.9836                                  King County       WA
# 50   35.4437   139.6380  Unassigned Location (From Diamond Princess)     None
# 61   37.3541  -121.9552                                  Santa Clara       CA
# 63   48.0330  -121.8339                             Snohomish County       WA
# 64   41.1220   -73.7949                           Westchester County       NY

# %%
#Creating a dataframe of the areas outside of the US with covid cases in case I decide to use it later
world_covid = covid_data[(covid_data.country_region != 'US')]

world_covid.head(5)
# Out:
#    country_region          last_update  confirmed  deaths  recovered  \
# 0  Mainland China  2020-03-05T14:53:03      67466    2902      40592
# 1     South Korea  2020-03-05T09:03:09       6088      35         41
# 2           Italy  2020-03-05T17:43:03       3858     148        414
# 3            Iran  2020-03-05T13:43:04       3513     107        739
# 4  Mainland China  2020-03-05T09:23:03       1351       7       1181
#
#    latitude  longitude       city us_state
# 0   30.9756   112.2707      Hubei     None
# 1   36.0000   128.0000        NaN      NaN
# 2   43.0000    12.0000        NaN      NaN
# 3   32.0000    53.0000        NaN      NaN
# 4   23.3417   113.4244  Guangdong     None

# %%
#Dropping the us_state column since it's not relevant 
world_covid = world_covid.drop(columns=['us_state'])

world_covid.head(5)
# Out:
#    country_region          last_update  confirmed  deaths  recovered  \
# 0  Mainland China  2020-03-05T14:53:03      67466    2902      40592
# 1     South Korea  2020-03-05T09:03:09       6088      35         41
# 2           Italy  2020-03-05T17:43:03       3858     148        414
# 3            Iran  2020-03-05T13:43:04       3513     107        739
# 4  Mainland China  2020-03-05T09:23:03       1351       7       1181
#
#    latitude  longitude       city
# 0   30.9756   112.2707      Hubei
# 1   36.0000   128.0000        NaN
# 2   43.0000    12.0000        NaN
# 3   32.0000    53.0000        NaN
# 4   23.3417   113.4244  Guangdong

# %%
#Connecting to postgres 
engine=create_engine(f'postgresql://postgres:Elatstaples57@localhost:5432/Homework')
engine.table_names()
# Out:
# ['departments',
#  'dept_emp',
#  'employees',
#  'salaries',
#  'titles',
#  'dept_manager',
#  'major_category',
#  'detail_category',
#  'us_covid']

# %%
#Loading dataframes into tables in postgres
major_cat.to_sql(name='major_category', con=engine, if_exists='append', index=False)
detail_cat.to_sql(name='detail_category', con=engine, if_exists='append', index=False)
US_covid.to_sql(name='us_covid', con=engine, if_exists='append', index=False)
#world_covid.to_sql(name='World_Covid', con=engine, if_exists='append', index=False)

# %%
#Creating a dataframe of the total deaths by state and the major occupations of the state by querying the created tables
pd.read_sql_query('Select detail_category.st as state_abr, major_category.occ_title as master_occupation_title, major_category.tot_emp as master_total_employment, detail_category.occ_title as detail_occupation_title, detail_category.tot_emp as detail_total_employment, SUM(us_covid.confirmed) as confirmed_cases, SUM(us_covid.deaths) as deaths, SUM(us_covid.recovered) as recovered From detail_category join major_category on detail_category.st = major_category.st join us_covid on detail_category.st = us_covid.us_state Group by state_abr, master_occupation_title, master_total_employment, detail_occupation_title, detail_total_employment Order By state_abr;', con=engine)
# Out:
#    state_abr                        master_occupation_title  \
# 0         AZ  Office and Administrative Support Occupations
# 1         CA  Office and Administrative Support Occupations
# 2         FL  Office and Administrative Support Occupations
# 3         GA  Office and Administrative Support Occupations
# 4         IL  Office and Administrative Support Occupations
# 5         MA  Office and Administrative Support Occupations
# 6         NC  Office and Administrative Support Occupations
# 7         NH  Office and Administrative Support Occupations
# 8         NJ  Office and Administrative Support Occupations
# 9         NV  Office and Administrative Support Occupations
# 10        NY  Office and Administrative Support Occupations
# 11        OR  Office and Administrative Support Occupations
# 12        RI  Office and Administrative Support Occupations
# 13        TN  Office and Administrative Support Occupations
# 14        TX  Office and Administrative Support Occupations
# 15        WA  Office and Administrative Support Occupations
# 16        WI  Office and Administrative Support Occupations
#
#     master_total_employment  \
# 0                  472350.0
# 1                 2438780.0
# 2                 1452150.0
# 3                  643490.0
# 4                  890740.0
# 5                  496690.0
# 6                  629880.0
# 7                  107820.0
# 8                  644040.0
# 9                  204430.0
# 10                1480630.0
# 11                 275850.0
# 12                  72280.0
# 13                 468630.0
# 14                1994750.0
# 15                 442170.0
# 16                 409200.0
#
#                               detail_occupation_title  \
# 0                    Customer Service Representatives
# 1                                 Personal Care Aides
# 2                                 Retail Salespersons
# 3                                 Retail Salespersons
# 4                                 Retail Salespersons
# 5                                 Retail Salespersons
# 6   Combined Food Preparation and Serving Workers,...
# 7                                 Retail Salespersons
# 8   Laborers and Freight, Stock, and Material Move...
# 9                                 Retail Salespersons
# 10                                Retail Salespersons
# 11                                Retail Salespersons
# 12                                Retail Salespersons
# 13  Laborers and Freight, Stock, and Material Move...
# 14                                Retail Salespersons
# 15                                Retail Salespersons
# 16                                Retail Salespersons
#
#     detail_total_employment  confirmed_cases  deaths  recovered
# 0                  101290.0                2       0          1
# 1                  558350.0               51       1          2
# 2                  336060.0                4       0          0
# 3                  144770.0                2       0          0
# 4                  168130.0                5       0          2
# 5                  100970.0                2       0          1
# 6                  147170.0                1       0          0
# 7                   24750.0                2       0          0
# 8                  141660.0                2       0          0
# 9                   46420.0                1       0          0
# 10                 301670.0               23       0          0
# 11                  57530.0                3       0          0
# 12                  13620.0                2       0          0
# 13                  95200.0                1       0          0
# 14                 396330.0                4       0          0
# 15                 103220.0               70      11          1
# 16                  81160.0                1       0          1
